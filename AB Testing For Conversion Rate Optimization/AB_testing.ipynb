# %%
import numpy as np

# %%
table = np.array([[75,557],[120,512]])
#convert data to numpy array in order to conduct statistical analysis on it.

# %%
from scipy.stats import chi2_contingency
#python package to import statistical test

# %%
res = chi2_contingency(table)

# %%
res
# Out:
# Chi2ContingencyResult(statistic=np.float64(11.739243481806625), pvalue=np.float64(0.0006119589368385762), dof=1, expected_freq=array([[ 97.5, 534.5],
#        [ 97.5, 534.5]]))

# %%
from scipy.stats import fisher_exact

# %%
res2 = fisher_exact(table)

# %%
res2
# Out:
# SignificanceResult(statistic=np.float64(0.5745062836624776), pvalue=np.float64(0.0005864970403527071))
